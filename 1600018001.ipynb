# %%
from sklearn.cluster import AgglomerativeClustering

# %%
from sklearn.datasets import make_blobs

# %%
X,y = make_blobs(random_state=0, n_samples=1000)

# %%
x
# Out:
# array([[-0.80723584,  2.66946295],
#        [ 1.9263585 ,  4.15243012],
#        [-1.50016563,  3.10133251],
#        ...,
#        [ 0.41230223,  0.49159186],
#        [-2.53294087,  2.09633244],
#        [ 1.10777893,  1.14210712]])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(X[:,0],X[:,1],'ro')
plt.show()

# %% [markdown]
# clustering = AgglomerativeClustering(n_clusters=3, linkage="ward", affinity='euclidean')

# %%
clustering = AgglomerativeClustering(n_clusters=3, linkage="ward", affinity='euclidean')

# %%
clustering.fit(X)
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#             connectivity=None, linkage='ward',
#             memory=Memory(cachedir=None), n_clusters=3,
#             pooling_func=<function mean at 0x0000000006377AC8>)

# %%
plt.scatter(X[:,0],X[:,1],c=clustering.labels_, marker='o')
plt.show()

# %%
clustering2 = AgglomerativeClustering(n_clusters=3, linkage="complete", affinity='manhattan')
clustering2.fit(X)
plt.scatter(X[:,0],X[:,1],c=clustering2.labels_, marker='o')
plt.show()

# %%
clustering3 = AgglomerativeClustering(n_clusters=3, linkage="average", affinity='manhattan')
clustering3.fit(X)
plt.scatter(X[:,0],X[:,1],c=clustering3.labels_, marker='o')
plt.show()
